# %% [markdown]
# **Player Count**
#
# * Total Number of Players
#
# **Purchasing Analysis (Total)**
#
# * Number of Unique Items
# * Average Purchase Price
# * Total Number of Purchases
# * Total Revenue
#
# **Gender Demographics**
#
# * Percentage and Count of Male Players
# * Percentage and Count of Female Players
# * Percentage and Count of Other / Non-Disclosed
#
# **Purchasing Analysis (Gender)**
#
# * The below each broken by gender
#   * Purchase Count
#   * Average Purchase Price
#   * Total Purchase Value
#   * Normalized Totals
#
# **Age Demographics**
#
# * The below each broken into bins of 4 years (i.e. &lt;10, 10-14, 15-19, etc.)
#   * Purchase Count
#   * Average Purchase Price
#   * Total Purchase Value
#   * Normalized Totals
#
# **Top Spenders**
#
# * Identify the the top 5 spenders in the game by total purchase value, then list (in a table):
#   * SN
#   * Purchase Count
#   * Average Purchase Price
#   * Total Purchase Value
#
# **Most Popular Items**
#
# * Identify the 5 most popular items by purchase count, then list (in a table):
#   * Item ID
#   * Item Name
#   * Purchase Count
#   * Item Price
#   * Total Purchase Value
#
# **Most Profitable Items**
#
# * Identify the 5 most profitable items by total purchase value, then list (in a table):
#   * Item ID
#   * Item Name
#   * Purchase Count
#   * Item Price
#   * Total Purchase Value

# %%
#dependencies
import pandas as pd
import os
import numpy as np

# %%
#determine whether we need to merge two or more files

passed_merge_input = False
passed_confirmation_input = False
while passed_merge_input != True:
    merge_choice = input("Would you like to use (1) file or merge (2)?")
    if merge_choice == '2':
        passed_merge_input = True
        print("Great let's merge your files.")
    elif merge_choice == '1':
        passed_merge_input = True
    else:
        print("Sorry, I don't understand. Please select a valid choice.")
# Out:
# Would you like to use (1) file or merge (2)?2
# Great let's merge your files.

# %%
#process fork for when only 1 input file
if merge_choice == '1':
    file_name = input("Let's Analyze your file. Please enter a json file name in the same directory as this program excluding the extension.")                  
    #define usable file_path with user input
    
    file_path = (str(file_name) + ".json")
    
    #read json file and convert into dataframe
    
    full_table_df = pd.read_json(file_path)
    full_table_df

# %%
#process for 2 input files

while passed_confirmation_input != True:
    if merge_choice == '2':
        file_name = input("File 1 - Please enter a json file name in the same directory as this program, excluding the extension.")
        file_path = (str(file_name) + ".json")
        file_name2 = input("File 2 - Please enter a json file name in the same directory as this program, excluding the extension.")
        file_path2 = (str(file_name2) + ".json")
    confirmed = input("The files you selected are " + str(file_name) + ".json & " + str(file_name2) + ".json. Is this correct? (Y)")
    confirmed = confirmed.lower()
    if confirmed == 'y':
        print("Preparing Output")
        passed_confirmation_input = True
    
full_table_df2 = pd.read_json(file_path)
full_table_df3 = pd.read_json(file_path2)

full_table_df = pd.merge(full_table_df2, full_table_df3, how='outer')

# %%
full_table_df = full_table_df.dropna(axis='index', how='any')
full_table_df
# Out:
#      Age  Gender  Item ID                                  Item Name  Price  \
# 0     38    Male      165                Bone Crushing Silver Skewer   3.37
# 1     21    Male      119  Stormbringer, Dark Blade of Ending Misery   2.32
# 2     34    Male      174                            Primitive Blade   2.46
# 3     21    Male       92                               Final Critic   1.36
# 4     23    Male       63                             Stormfury Mace   1.27
# 5     20    Male       10                                Sleepwalker   1.73
# 6     20    Male      153                            Mercenary Sabre   4.57
# 7     29  Female      169     Interrogator, Blood Blade of the Queen   3.32
# 8     25    Male      118           Ghost Reaver, Longsword of Magic   2.77
# 9     31    Male       99       Expiration, Warscythe Of Lost Worlds   4.53
# 10    24    Male       57            Despair, Favor of Due Diligence   3.81
# 11    20    Male       47                Alpha, Reach of Ending Hope   1.55
# 12    30    Male       81                                  Dreamkiss   4.06
# 13    23    Male       77                 Piety, Guardian of Riddles   3.68
# 14    40    Male       44                      Bonecarvin Battle Axe   2.46
# 15    21    Male       96                Blood-Forged Skeletal Spine   4.77
# 16    22  Female      123                          Twilight's Carver   1.14
# 17    22  Female       59              Lightning, Etcher of the King   1.65
# 18    28    Male       91                                    Celeste   3.71
# 19    31    Male      177   Winterthorn, Defender of Shifting Worlds   4.89
# 20    24    Male       78                 Glimmer, Ender of the Moon   2.33
# 21    15    Male        3                               Phantomlight   1.79
# 22    11  Female       11                                  Brimstone   2.52
# 23    19    Male      183                        Dragon's Greatsword   2.36
# 24    11    Male       65                  Conqueror Adamantite Mace   1.96
# 25    21    Male       63                             Stormfury Mace   1.27
# 26    29    Male      132                                 Persuasion   3.90
# 27    34    Male      106                        Crying Steel Sickle   2.29
# 28    15    Male       49           The Oculus, Token of Lost Worlds   4.23
# 29    16  Female       45                        Glinting Glass Edge   2.46
# ..   ...     ...      ...                                        ...    ...
# 828   25    Male       84                                 Arcane Gem   4.81
# 829   20    Male       14                             Possessed Core   2.82
# 830   23    Male      176                     Relentless Iron Skewer   2.12
# 831   28    Male        1                                   Crucifer   3.67
# 832   23  Female      118           Ghost Reaver, Longsword of Magic   2.95
# 833   16  Female       94                             Mourning Blade   3.64
# 834   25    Male      111                               Misery's End   1.79
# 835   20    Male      108  Extraction, Quickblade Of Trembling Hands   2.26
# 836   17    Male       79                        Alpha, Oath of Zeal   1.31
# 837   23  Female      107                  Splitter, Foe Of Subtlety   4.15
# 838   30  Female      105               Hailstorm Shadowsteel Scythe   1.02
# 839   39  Female        2                                    Verdict   2.65
# 840   23  Female       68          Storm-Weaver, Slayer of Inception   4.39
# 841   21    Male       31                                  Trickster   4.59
# 842   18    Male       25                                  Hero Cane   4.78
# 843   11  Female       41                                      Orbit   3.85
# 844   24    Male      164                           Exiled Doomblade   1.31
# 845   23    Male      181                              Reaper's Toll   4.12
# 846   24    Male        4                         Bloodlord's Fetish   1.91
# 847   22    Male       94                             Mourning Blade   3.64
# 848   21    Male       82                                    Nirvana   1.77
# 849   34    Male      126                   Exiled Mithril Longsword   1.08
# 850   25    Male       98                Deadline, Voice Of Subtlety   1.29
# 851   25    Male       60                                       Wolf   2.70
# 852   21    Male      180                                Stormcaller   2.77
# 853   35    Male       93                   Apocalyptic Battlescythe   4.49
# 854   38    Male      163                       Thunderfury Scimitar   4.16
# 855   15    Male      167                Malice, Legacy of the Queen   3.25
# 856   24    Male       97                Swan Song, Gouger Of Terror   1.92
# 857   20    Male      134                            Undead Crusader   2.15
#
#                   SN
# 0          Aelalis34
# 1             Eolo46
# 2        Assastnya25
# 3       Pheusrical25
# 4             Aela59
# 5         Tanimnya91
# 6        Undjaskla97
# 7       Iathenudil29
# 8       Sondenasta63
# 9         Hilaerin92
# 10        Chamosia29
# 11           Sally64
# 12         Iskossa88
# 13   Seorithstilis90
# 14         Sundast29
# 15        Haellysu29
# 16        Sundista85
# 17         Aenarap34
# 18         Iskista88
# 19         Assossa43
# 20           Irith83
# 21       Iaralrgue74
# 22          Deural48
# 23        Chanosia65
# 24          Qarwen67
# 25            Idai61
# 26     Aerithllora36
# 27       Assastnya25
# 28       Ilariarin45
# 29         Phaedai25
# ..               ...
# 828          Eusty71
# 829      Frichilsa31
# 830          Filon68
# 831         Palyon91
# 832      Assistast50
# 833      Seostylis96
# 834        Iskadar31
# 835     Pheodaisun84
# 836         Yarmol79
# 837           Aeri79
# 838       Undosian34
# 839      Aesririam61
# 840          Firon67
# 841       Jiskjask76
# 842       Chanirra64
# 843      Isristira52
# 844       Chaniman66
# 845     Yarithrgue83
# 846           Airi27
# 847       Undilsan50
# 848        Aidaira26
# 849        Chamalo71
# 850        Undadar97
# 851        Sundaky74
# 852        Lisirra44
# 853        Chamast86
# 854         Ardcil81
# 855         Heudai45
# 856       Chaniman66
# 857    Syalallodil59
#
# [858 rows x 6 columns]

# %%
nPlayers = full_table_df[['SN']].nunique()
TotalPlayers_df = pd.DataFrame({'Total Players':nPlayers})

# %%
TotalPlayers_df
# Out:
#     Total Players
# SN            612

# %%
nUniqueItems = full_table_df['Item ID'].nunique()
avgPrice = full_table_df['Price'].mean()
nPurchases = full_table_df.count(axis=0)
totalRevenue = full_table_df['Price'].sum()

purchasingAnalysis_df = pd.DataFrame({'Unique Items': nUniqueItems, 
                                     'Average Purchase Price': avgPrice,
                                     'Total Number of Purchases': nPurchases,
                                     'Total Revenue':totalRevenue})

purchases = len(full_table_df.index)

# %%
#Percentage and Count of Male Players
#Percentage and Count of Female Players
#Percentage and Count of Other / Non-Disclosed

gender_df = full_table_df.groupby('Gender')

genderpurchase = gender_df['SN'].count()
genderpurchase_df = pd.DataFrame({
    "Count" : genderpurchase,
    "Percentage" : genderpurchase/purchases})

genderpurchase_df
# Out:
#                        Count  Percentage
# Gender
# Female                   149    0.173660
# Male                     697    0.812354
# Other / Non-Disclosed     12    0.013986

# %%
'''
The below each broken by gender
Purchase Count
Average Purchase Price
Total Purchase Value
Normalized Totals
'''

gender_sum = full_table_df.groupby(by='Gender')['Price'].sum()
gender_avg = full_table_df.groupby(by='Gender')['Price'].mean()
gender_total = full_table_df.groupby(by='Gender')['SN'].count()
gender_total_normal = full_table_df.groupby(by='Gender')['Price'].sum()

gender_analysis_df = pd.DataFrame({
    "Purchase Sum" : gender_sum,
    "Purchase Average" : round(gender_avg, 2),
    "Purchase Count" : gender_total,
    "Normalized Total" : gender_total_normal})

gender_analysis_df = gender_analysis_df[['Purchase Sum', 
                                        'Purchase Average', 
                                        'Purchase Count', 
                                        'Normalized Total']]
gender_analysis_df
# Out:
#                        Purchase Sum  Purchase Average  Purchase Count  \
# Gender
# Female                       424.29              2.85             149
# Male                        2052.28              2.94             697
# Other / Non-Disclosed         37.86              3.15              12
#
#                        Normalized Total
# Gender
# Female                           424.29
# Male                            2052.28
# Other / Non-Disclosed             37.86

# %%
'''
The below each broken into bins of 4 years (i.e. <10, 10-14, 15-19, etc.)
Purchase Count
Average Purchase Price
Total Purchase Value
Normalized Totals
'''

bins = [0, 9, 14, 19, 24, 29, 34, 39, 44, 49]
full_table_df['Age Bracket'] = pd.cut(full_table_df['Age'], bins)

binned_sum = full_table_df.groupby(by='Age Bracket')['Price'].sum()
binned_avg = full_table_df.groupby(by='Age Bracket')['Price'].mean()
binned_total = full_table_df.groupby(by='Age Bracket')['SN'].count()
binned_total_normal = full_table_df.groupby(by='Age Bracket')['Price'].sum()

binned_analysis_df = pd.DataFrame({
    "Purchase Sum" : binned_sum,
    "Purchase Average" : round(binned_avg, 2),
    "Purchase Count" : binned_total,
    "Normalized Total" : binned_total_normal})

binned_analysis_df = binned_analysis_df[['Purchase Sum', 
                                        'Purchase Average', 
                                        'Purchase Count', 
                                        'Normalized Total']]
binned_analysis_df
# Out:
#              Purchase Sum  Purchase Average  Purchase Count  Normalized Total
# Age Bracket
# (0, 9]              83.46              2.98              28             83.46
# (9, 14]             96.95              2.77              35             96.95
# (14, 19]           386.42              2.91             133            386.42
# (19, 24]           978.77              2.91             336            978.77
# (24, 29]           370.33              2.96             125            370.33
# (29, 34]           197.25              3.08              64            197.25
# (34, 39]           119.40              2.84              42            119.40
# (39, 44]            51.03              3.19              16             51.03
# (44, 49]             2.72              2.72               1              2.72

# %%
'''
Top Spenders

Identify the the top 5 spenders in the game by total purchase value, then list (in a table):
SN
Purchase Count
Average Purchase Price
Total Purchase Value
'''

player_num = full_table_df.groupby(by='SN')['SN'].max()
player_count = full_table_df.groupby(by='SN')['Price'].count()
player_avg = full_table_df.groupby(by='SN')['Price'].mean()
player_total = full_table_df.groupby(by='SN')['Price'].sum()

player_analysis_df = pd.DataFrame({
    "Serial Number" : player_num,
    "Purchase Count" : player_count,
    "Average Purchase Price" : player_avg,
    "Total Purchase Value" : player_total})
    
player_analysis_df = player_analysis_df[['Serial Number', 
                                        'Average Purchase Price', 
                                        'Purchase Count', 
                                        'Total Purchase Value']]

player_analysis_df.sort_values(by='Total Purchase Value', ascending=False).head(5)
# Out:
#                Serial Number  Average Purchase Price  Purchase Count  \
# SN
# Undirrala66      Undirrala66                   3.412               5
# Aerithllora36  Aerithllora36                   3.775               4
# Saedue76            Saedue76                   3.390               4
# Sondim43            Sondim43                   3.255               4
# Mindimnya67      Mindimnya67                   3.185               4
#
#                Total Purchase Value
# SN
# Undirrala66                   17.06
# Aerithllora36                 15.10
# Saedue76                      13.56
# Sondim43                      13.02
# Mindimnya67                   12.74

# %%
'''
Most Popular Items

Identify the 5 most popular items by purchase count, then list (in a table):
Item ID
Item Name
Purchase Count
Item Price
Total Purchase Value
'''
item_id = full_table_df.groupby(by='Item ID')['Item ID'].max()
item_name = full_table_df.groupby(by='Item ID')['Item Name'].max()
item_count = full_table_df.groupby(by='Item ID')['Price'].count()
item_price = full_table_df.groupby(by='Item ID')['Price'].max()
item_total = full_table_df.groupby(by='Item ID')['Price'].sum()

item_analysis_df = pd.DataFrame({
    "Item ID" : item_id,
    "Item Name" : item_name,
    "Purchase Count" : item_count,
    "Item Price" : item_price,
    "Total Purchase Value" : item_total})
    
item_analysis_df = item_analysis_df[['Item ID', 
                                        'Item Name', 
                                        'Purchase Count', 
                                        'Item Price',
                                        'Total Purchase Value']]

item_analysis_df.sort_values(by='Purchase Count', ascending=False).head(5)
# Out:
#          Item ID                             Item Name  Purchase Count  \
# Item ID
# 39            39  Betrayal, Whisper of Grieving Widows              11
# 84            84                            Arcane Gem              11
# 31            31                             Trickster               9
# 175          175            Woeful Adamantite Claymore               9
# 13            13                              Serenity               9
#
#          Item Price  Total Purchase Value
# Item ID
# 39             2.35                 25.85
# 84             2.23                 24.53
# 31             2.07                 18.63
# 175            1.24                 11.16
# 13             1.49                 13.41

# %%
'''
Identify the 5 most profitable items by total purchase value, then list (in a table):
Item ID
Item Name
Purchase Count
Item Price
Total Purchase Value
'''
profit_id = full_table_df.groupby(by='Item ID')['Item ID'].max()
profit_name = full_table_df.groupby(by='Item ID')['Item Name'].max()
profit_count = full_table_df.groupby(by='Item ID')['Price'].count()
profit_price = full_table_df.groupby(by='Item ID')['Price'].max()
profit_total = full_table_df.groupby(by='Item ID')['Price'].sum()

profit_analysis_df = pd.DataFrame({
    "Item ID" : profit_id,
    "Item Name" : profit_name,
    "Purchase Count" : profit_count,
    "Item Price" : profit_price,
    "Total Purchase Value" : profit_total})
    
profit_analysis_df = item_analysis_df[['Item ID', 
                                        'Item Name', 
                                        'Purchase Count', 
                                        'Item Price',
                                        'Total Purchase Value']]

profit_analysis_df.sort_values(by='Item Price', ascending=False).head(5)
# Out:
#          Item ID                                 Item Name  Purchase Count  \
# Item ID
# 32            32                                   Orenmir               6
# 177          177  Winterthorn, Defender of Shifting Worlds               4
# 103          103                            Singed Scalpel               6
# 173          173                       Stormfury Longsword               5
# 131          131                                      Fury               4
#
#          Item Price  Total Purchase Value
# Item ID
# 32             4.95                 29.70
# 177            4.89                 19.56
# 103            4.87                 29.22
# 173            4.83                 24.15
# 131            4.82                 19.28
